# %%
import pandas as pd
pd.read_csv("C:/Users/alexs/OneDrive/Desktop/MLB/data/pitching24.csv", encoding = "latin1")
# Out:
#        Rk            Player  Age Team  Lg  WAR   W   L   W-L%   ERA  ...  \
# 0       1     Logan Gilbert   27  SEA  AL  2.8   9  12  0.429  3.23  ...
# 1       2         Seth Lugo   34  KCR  AL  5.3  16   9  0.640  3.00  ...
# 2       3        Logan Webb   27  SFG  NL  3.7  13  10  0.565  3.47  ...
# 3       4      Zack Wheeler   34  PHI  NL  6.1  16   7  0.696  2.57  ...
# 4       5        Aaron Nola   31  PHI  NL  3.6  14   8  0.636  3.57  ...
# ..    ...               ...  ...  ...  ..  ...  ..  ..    ...   ...  ...
# 848  1090      Miguel SanÃ³   31  LAA  AL  0.0   0   0    NaN  0.00  ...
# 849  1091      Luis Torrens   28  NYM  NL  0.0   0   0    NaN  0.00  ...
# 850  1092    Patrick Wisdom   32  CHC  NL  0.0   0   0    NaN  0.00  ...
# 851  1093  Carl Edwards Jr.   32  SDP  NL  0.0   0   0    NaN   NaN  ...
# 852  1094      Wander Suero   32  HOU  AL  0.0   0   1  0.000   NaN  ...
#
#      HardH%    LD%    GB%   FB%  GB/FB  WPA    cWPA   RE24         Awards.1  \
# ...
